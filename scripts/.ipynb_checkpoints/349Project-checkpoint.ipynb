# %%
from time import time
import pandas as pd
import re
import numpy as np
from wordcloud import WordCloud
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import Perceptron, LogisticRegression
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from ast import literal_eval

# %%
#globals

# %%
#read csv into pandas
df = pd.read_csv("glassdoorclean.csv")

# %%
def initial_clean():
    del df['Listing ID']
    del df['Listing State']
    del df['HQ State']
    del df['Company']
    df.dropna()

# %%
def get_seniority():
    seniorityArr = ['principal', 'manager', 'junior', 'jr', 'jr.', 'lead', 'snr', 'senior', 'sr', 'sr.', 'director', 'associate', 'i', 'ii', 'intern', 'iii', 'iv', '1', '2', '3', '4', 'grad']
    seniority = {
        'manager': ['manager'],
        'junior' : ['junior', 'jr'],
        'principal' : ['principal'],
        'director': ['director'],
        'lead': ['lead'],
        'senior' : ['senior', 'sr', 'snr'],
        'intern' : ['intern'],
        'associate': ['associate'],
        'one' : ['i', '1', ],
        'two' : ['ii', '2'],
        'three' : ['iii', '3'],
        'four' : ['iv', '4'],
        'grad' : ['grad', 'graduate'],
    }
    
    position = []
    for title in df['Job Title']:
        t = re.split(r'\W+', title)
        res = ""
        if not set(t).isdisjoint(seniorityArr):
            for name, ls in seniority.items():
                if not set(t).isdisjoint(ls):
                    res = name
                    break
        else:
            res = "none"
        position.append(res)
    df['Seniority'] = position
    del df['Job Title']

# %%
def parse_description():
    desc = []
    for row in df['Description']:
        desc.append(literal_eval(row))
    df['Description'] = desc

# %%
def get_average_salary():
    df['Avg Salary'] = 1000 * ((df['Salary Low (K)'] + df['Salary High (K)']) / 2)
    del df['Salary Low (K)']
    del df['Salary High (K)']

# %%
##https://stackoverflow.com/questions/19913659/pandas-conditional-creation-of-a-series-dataframe-column
def make_rating_ranges(df):
    conditions = [
        4.5 <= df['Company Rating'],
        (4 <= df['Company Rating']) & (df['Company Rating'] < 4.5),
        (3.5 <= df['Company Rating']) & (df['Company Rating'] < 4),
        (3 <= df['Company Rating']) & (df['Company Rating'] <= 3.5),
        df['Company Rating'] < 3
    ]
    choices = [5,4,3,2,1]
    df['Rating'] = np.select(conditions, choices, default='0')
    df.drop(df[df['Rating'] == '0'].index, inplace=True)

# %%
initial_clean()
get_seniority()
parse_description()
get_average_salary()
make_rating_ranges(df)
df
# Out:
#       Company Rating      Listing City  \
# 0                3.7            Warren
# 1                3.7       Santa Clara
# 2                3.2          New York
# 3                4.0       Mill Valley
# 4                4.1  Farmington Hills
# 5                3.2     San Francisco
# 6                2.9          New York
# 7                3.7       Los Angeles
# 8                3.0         Weehawken
# 9                3.7          New York
# 10               3.7           Chicago
# 11               3.9           Oakland
# 12               4.1           Seattle
# 13               4.1           Seattle
# 14               4.4           Bedford
# 15               3.8           Seattle
# 16               3.5     San Francisco
# 17               4.3      Santa Monica
# 18               3.6         Irwindale
# 19               3.5           Chicago
# 20               2.9        Menlo Park
# 21               4.0       Los Angeles
# 22               3.3           Chicago
# 23               2.9          New York
# 24               4.1           Seattle
# 25               3.9          New York
# 26               3.0          New York
# 27               2.9          Bellevue
# 28               3.1        Pittsburgh
# 29               4.5     San Francisco
# ...              ...               ...
# 6542             3.1        Framingham
# 6543             4.4       Santa Clara
# 6544             4.2          New York
# 6545             4.0           Chicago
# 6546             3.8     San Francisco
# 6547             3.6            Austin
# 6548             4.1           Detroit
# 6549             2.5            Austin
# 6550             4.2     San Francisco
# 6551             3.1           Waltham
# 6552             3.5            Austin
# 6553             3.1     San Francisco
# 6554             3.8          Hartford
# 6555             4.1           Seattle
# 6556             3.7          New York
# 6557             3.2       Foster City
# 6558             4.1           Chicago
# 6559             4.1           Detroit
# 6560             3.6          San Jose
# 6561             3.3          Dearborn
# 6562             3.6            Boston
# 6563             3.9            Boston
# 6564             3.2           Oakland
# 6565             3.2           Fremont
# 6566             3.0           Chicago
# 6567             3.8         Cambridge
# 6568             3.3           Seattle
# 6569             3.5            Austin
# 6570             3.8           Chicago
# 6571             3.7          New York
#
#                                             Description           HQ City  \
# 0     [areapplied, teams, gmvehicle, these, vehicle,...           Detroit
# 1     [action, a, physical, regulatory, in, issues, ...        SantaClara
# 2     [talentresourceteam, out, than, produces, line...           NewYork
# 3     [jobs, technical, proven, under, very, systems...        MillValley
# 4     [planning, presentation, optical, analyses, co...             Paris
# 5     [role, applications, custom, key, analysts, cr...      SanFrancisco
# 6     [than, united, order, helpduties, conducts, el...            Denver
# 7     [diagramming, interested, direct, presentation...         ElSegundo
# 8     [profile, warehousing, flow, role, apply, plus...           NewYork
# 9     [marital, be, project, equal, collaborative, d...           Norwood
# 10    [role, planning, direct, marketplace, part, te...           Chicago
# 11    [firmwide, quality, job, us, apply, location, ...      SanFrancisco
# 12    [around, application, project, beauty., until,...           Seattle
# 13    [an, submissions, development, hutchinson, con...           Seattle
# 14    [best, making, but, also, applicant., directly...           Bedford
# 15    [efficient, prove, join, to, both, cloud, one,...           Seattle
# 16    [go, planners, teams, custom, u.s., cutting, a...           NewYork
# 17    [reports, specific, than, ca, personalized, va...       SantaMonica
# 18    [go, scientific, disability., functions., guid...            Duarte
# 19    [interested, uniformity., pricing, key, applic...           Chicago
# 20    [teams, gaps, cross, scorecards, action, partn...           Fremont
# 21    [implementation, out, closing, ..., on, pipeli...           Oakland
# 22    [familiarity, modeling, computing, electrical,...            Irving
# 23    [form, improvements, party, curious, dashboard...      BeverlyHills
# 24    [inactive, field., uw, preparing, improve, int...           Seattle
# 25    [portable, interact, people., detection, equiv...           NewYork
# 26    [out, queries, learning, profile, regression, ...           NewYork
# 27    [efficiently, orders, production, massively, i...      SanFrancisco
# 28    [security, projects., strategy, execute, ticke...        Pittsburgh
# 29    [places, comprehensive, data, provide, live, a...            Weston
# ...                                                 ...               ...
# 6542  [ambiguity, exposing, seeking, them, etl, sour...        Framingham
# 6543  [role, an, improve, cross, concerns, turning, ...        SantaClara
# 6544  [passion, stores, similar, availability, drive...           Milford
# 6545  [responsibilities, focal, labor, activities., ...           Chicago
# 6546  [qualifications, teams, custom, these, key, pu...      SanFrancisco
# 6547  [implementation, responsibilities, align, orie...            Austin
# 6548  [position, posting, 3, college, institutes, me...           Detroit
# 6549  [applying, serve., tx, software, commercial, s...       FlorhamPark
# 6550  [role, part, goals, improve, teams, cutting, r...      SanFrancisco
# 6551  [implementation, reports, responsibilities, do...  AlphenaandenRijn
# 6552  [conversations, reports, than, religion, align...           Atlanta
# 6553  [citizenship, why, no, otherwise, director, pl...              Lehi
# 6554  [influence, changing, statistical, to, solutio...          Hartford
# 6555  [send, join, include, service, to, solutions.,...           Seattle
# 6556  [teams, confidence, threatconnects, ct, want, ...         Arlington
# 6557  [jobs, et, faire, informatique, du, suppressio...        FosterCity
# 6558  [complete, ca, with., labor, software, restora...      SanFrancisco
# 6559  [analyst, of, college, division, vacancies, ce...           Detroit
# 6560  [use, a, proud, in, using, test, poster, resea...           SanJose
# 6561  [teams, analysts, process, used, processes, re...   BloomfieldHills
# 6562  [track, presentation, qualifications, meetings...            Boston
# 6563  [reports, responsibilities, epic, tableau, var...            Boston
# 6564  [programming, common, skills, create, organize...        Copenhagen
# 6565  [modeling, project, 3, in, products, purpose, ...           Houston
# 6566  [planning, goals, u.s., reach, innovating, act...           Chicago
# 6567  [history, project, addition, visualizations, 3...        Washington
# 6568  [resources, salary, apply, screen, life, also,...           Seattle
# 6569  [domain, software, evaluates, work, members, a...           Atlanta
# 6570  [analytics, responsibilities, techniques, find...           NewYork
# 6571  [role, sports, teams, buildings, progress, des...           NewYork
#
#      Company Size                       Industry  Seniority  Avg Salary Rating
# 0          10000+                  Manufacturing       lead     85000.0      3
# 1          10000+        Biotech&Pharmaceuticals       none     86500.0      3
# 2         < 10000                          Media     junior    107500.0      2
# 3          < 1000          InformationTechnology       lead    139500.0      4
# 4         < 10000                  Manufacturing        two     81500.0      4
# 5         < 10000                      Insurance       lead    125000.0      2
# 6          < 1000                     Government       none     94000.0      1
# 7           < 200          InformationTechnology     senior     79500.0      3
# 8           < 200               BusinessServices       none    121000.0      2
# 9          < 1000               BusinessServices       none     60000.0      3
# 10          < 500  Arts,Entertainment&Recreation     senior    101500.0      3
# 11        < 10000               BusinessServices       none     62500.0      3
# 12         10000+                      Education        one     40000.0      4
# 13         < 5000                     Non-Profit       none     67000.0      4
# 14         < 1000                         Retail     intern     63500.0      4
# 15         10000+          InformationTechnology       none    114500.0      3
# 16         10000+                        Finance       none    135500.0      3
# 17          < 200                        Finance     senior     88500.0      4
# 18        < 10000                     HealthCare       none     88500.0      3
# 19         < 5000                      Insurance       none    105500.0      3
# 20         < 1000          InformationTechnology        two     79500.0      1
# 21         10000+                      Education     senior    133000.0      4
# 22        < 10000               BusinessServices       none    135500.0      2
# 23         < 5000                          Media   director    114000.0      1
# 24         10000+                      Education       none     63500.0      4
# 25         10000+                     HealthCare  associate     58500.0      3
# 26          < 200               BusinessServices       none    121000.0      2
# 27         < 1000          InformationTechnology     senior    134000.0      1
# 28         < 1000                      Education       none     89500.0      2
# 29         < 5000          InformationTechnology     senior    199500.0      5
# ...           ...                            ...        ...         ...    ...
# 6542       10000+                         Retail  principal    127000.0      2
# 6543       10000+          InformationTechnology       none    102500.0      4
# 6544        < 200          InformationTechnology       none     63500.0      4
# 6545        < 500                  Manufacturing       none     77000.0      4
# 6546        < 200                         Retail       none    156500.0      3
# 6547       < 1000                        Finance       none     74000.0      3
# 6548      < 10000                      Education       none     52500.0      4
# 6549       10000+               BusinessServices     senior    108500.0      1
# 6550       10000+          InformationTechnology       none    126500.0      4
# 6551       10000+          InformationTechnology     senior     76500.0      2
# 6552       10000+                        Unknown     senior    106500.0      3
# 6553       < 5000          InformationTechnology     senior    224000.0      2
# 6554       10000+                      Insurance       lead    111000.0      3
# 6555        < 500               BusinessServices       none     98000.0      4
# 6556        < 200          InformationTechnology       none    104500.0      3
# 6557      < 10000        Biotech&Pharmaceuticals  associate     92000.0      2
# 6558        < 500          InformationTechnology       none    121000.0      4
# 6559      < 10000                      Education       none     49000.0      4
# 6560       10000+                        Unknown       none    127500.0      3
# 6561       10000+                         Retail       none     68000.0      2
# 6562       < 5000        Biotech&Pharmaceuticals       none    104000.0      3
# 6563      < 10000                     HealthCare     senior     59500.0      3
# 6564       10000+                         Retail  principal    124500.0      2
# 6565       10000+                         Retail       none    136500.0      2
# 6566      < 10000                        Finance       none     92000.0      2
# 6567       10000+                     Government       none    102000.0      3
# 6568       10000+                     HealthCare       none     40500.0      2
# 6569       10000+                        Unknown    manager    165000.0      3
# 6570       10000+               Accounting&Legal  associate    123000.0      3
# 6571        < 500               BusinessServices       none     75000.0      3
#
# [6551 rows x 9 columns]

# %%
df.groupby('Rating').count()
# Out:
#         Company Rating  Listing City  Description  HQ City  Company Size  \
# Rating
# 1                  439           439          439      439           438
# 2                 1618          1618         1618     1618          1604
# 3                 2534          2527         2534     2534          2527
# 4                 1508          1507         1508     1508          1496
# 5                  452           452          452      452           452
#
#         Industry  Seniority  Avg Salary
# Rating
# 1            439        439         439
# 2           1618       1618        1618
# 3           2534       2534        2534
# 4           1508       1508        1508
# 5            452        452         452

# %%
def word_cloudify():
#make a word cloud to get a feel for what we're working with
#https://www.geeksforgeeks.org/generating-word-cloud-python/
#https://python.gotrained.com/text-classification-with-pandas-scikit/
    total_str = ""
    for listing in df['Description']:
        total_str += ' '.join(listing)
        wordcloud = WordCloud(width = 800, height = 800, 
                        background_color ='white',  
                        min_font_size = 12).generate(total_str)

    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 

    plt.show()
    
word_cloudify()

# %%
def bag_words(data):
    bag = {}
    word_count = 0
    for row in data['Description']:
        for word in row:
            if word not in bag:
                bag[word] = word_count
                word_count += 1
    
    return bag
 
bag = bag_words(df)

# %%
def get_features(description, bag):
    features = [0 for x in range(len(bag))]
    for word in description:
        ind = bag[word]
        features[ind] += 1
    return features

# %%
def get_all_features(data, bag):
    all_features = []
    for description in data['Description']:
        all_features.append(get_features(description, bag))
    return all_features

all_features = get_all_features(df, bag)

# %%
def export_feature_csv(df):
    export = df.filter(['Rating'], axis = 1)
    export['Features'] = all_features
    export.to_csv('withfeatures.csv', encoding='utf-8', index=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(all_features, df['Rating'], test_size=0.33, random_state=0)

# %%
#saved for comparison
print('zeroR accuracy: .387')
print('Perceptron(max_iter=50) accuracy: 0.653')
print('MultinomialNB(alpha=.01) accuracy: 0.695')
print('MultinomialNB(alpha=.001) accuracy: 0.702')
print('BernoulliNB(alpha=.01) accuracy: 0.685')
print('BernoulliNB(alpha=.001) accuracy: 0.698')
print('RandomForestClassifier() accuracy: 0.586')
print('LogisticRegression() accuracy: 0.672')
# Out:
# zeroR accuracy: .387
# Perceptron(max_iter=50) accuracy: 0.653
# MultinomialNB(alpha=.01) accuracy: 0.695
# MultinomialNB(alpha=.001) accuracy: 0.702
# BernoulliNB(alpha=.01) accuracy: 0.685
# RandomForestClassifier() accuracy: 0.586
# LogisticRegression() accuracy: 0.672

# %%
#clf = Perceptron(max_iter=50)
#clf = MultinomialNB(alpha=0.001)
clf = BernoulliNB(alpha=.0001)
#clf = RandomForestClassifier()
#clf = LogisticRegression()

clf.fit(X_train, y_train)
pred = clf.predict(X_test)
score = metrics.accuracy_score(y_test, pred)
print("accuracy:   %0.3f" % score)
# Out:
# accuracy:   0.697

# %%
print('Training size: {} Test Size: {}'.format(len(X_train), len(X_test)))
# Out:
# Training size: 4389 Test Size: 2162
